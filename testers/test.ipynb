# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./test_logs/stress_test1.csv")

# %%
df
# Out:
#     run_number    run_date       time_start         time_end      total_time  \
# 0            1  2022-10-12  00:55:01.131313  00:55:03.345633  0:00:02.214320
# 1            2  2022-10-12  00:55:03.501052  00:55:05.564695  0:00:02.063643
# 2            3  2022-10-12  00:55:05.721391  00:55:07.842424  0:00:02.121033
# 3            4  2022-10-12  00:55:07.997453  00:55:10.045805  0:00:02.048352
# 4            5  2022-10-12  00:55:10.201676  00:55:12.320772  0:00:02.119096
# ..         ...         ...              ...              ...             ...
# 95          96  2022-10-12  00:58:34.692773  00:58:36.814808  0:00:02.122035
# 96          97  2022-10-12  00:58:36.978221  00:58:39.063100  0:00:02.084879
# 97          98  2022-10-12  00:58:39.222150  00:58:41.279127  0:00:02.056977
# 98          99  2022-10-12  00:58:41.475354  00:58:43.539938  0:00:02.064584
# 99         100  2022-10-12  00:58:43.706038  00:58:45.776123  0:00:02.070085
#
#     success  fail
# 0       500     0
# 1       500     0
# 2       500     0
# 3       500     0
# 4       500     0
# ..      ...   ...
# 95      500     0
# 96      500     0
# 97      500     0
# 98      500     0
# 99      500     0
#
# [100 rows x 7 columns]

# %%
# transform total_time to epoch time
df["total_time"] = df["total_time"].apply(lambda x: pd.to_datetime(x).timestamp())

# %%
# Plot the total_time vs run_number
plt.plot(df["run_number"], df["total_time"])
plt.xlabel("Run Number")
plt.ylabel("Total Time (s)")
plt.title("Total Time vs Run Number")
# Plot a line for the mean
plt.axhline(df["total_time"].mean(), color="red", linestyle="--")
# Plot a line for the median
plt.axhline(df["total_time"].median(), color="green", linestyle="--")
# Plot a line for the max
plt.axhline(df["total_time"].max(), color="orange", linestyle="--")
# Plot a line for the min
plt.axhline(df["total_time"].min(), color="blue", linestyle="--")
# Legend
plt.legend(["Total Time", "Mean", "Median", "Max", "Min"])
plt.show()
