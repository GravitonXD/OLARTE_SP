# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Open cpu_stats and memory_stats files
cpu_stats = pd.read_csv('cpu_stats.csv')
memory_stats = pd.read_csv('memory_stats.csv')

# %%
cpu_stats.head(10)
# Out:
#    time(s)  preprocessor  alamAPI_API  alamAPI_DB
# 0        0          0.02         0.16        0.19
# 1        1          0.03         0.16        0.23
# 2        2          0.03         0.15        0.23
# 3        3          0.08         0.16        0.62
# 4        4          0.04         0.17        0.23
# 5        5          0.03         0.16        0.18
# 6        6          0.05         0.23        0.28
# 7        7          0.07         0.24        0.29
# 8        8          0.13         0.25        1.07
# 9        9          0.03         0.20        0.24

# %%
cpu_stats.describe()
# Out:
#            time(s)  preprocessor  alamAPI_API   alamAPI_DB
# count  3600.000000   3600.000000  3600.000000  3600.000000
# mean   1799.500000      0.028083     0.136497     0.211175
# std    1039.374812      0.016049     0.020599     0.111370
# min       0.000000      0.020000     0.110000     0.130000
# 25%     899.750000      0.020000     0.120000     0.160000
# 50%    1799.500000      0.020000     0.130000     0.170000
# 75%    2699.250000      0.030000     0.140000     0.200000
# max    3599.000000      0.160000     0.340000     1.440000

# %%
memory_stats.head(10)
# Out:
#    time(s)  preprocessor  alamAPI_API  alamAPI_DB
# 0        0         56.15        30.49       144.3
# 1        1         56.15        30.49       144.3
# 2        2         56.15        30.49       144.3
# 3        3         56.15        30.49       144.3
# 4        4         56.15        30.49       144.3
# 5        5         56.15        30.49       144.4
# 6        6         56.15        30.49       144.3
# 7        7         56.15        30.49       144.3
# 8        8         56.16        30.49       144.3
# 9        9         56.16        30.49       144.3

# %%
memory_stats.describe()
# Out:
#            time(s)  preprocessor   alamAPI_API   alamAPI_DB
# count  3600.000000   3600.000000  3.600000e+03  3600.000000
# mean   1799.500000     57.469211  3.049000e+01    64.753985
# std    1039.374812      0.654005  1.065962e-14    78.528470
# min       0.000000     56.150000  3.049000e+01     0.153320
# 25%     899.750000     57.790000  3.049000e+01     0.163086
# 50%    1799.500000     57.800000  3.049000e+01     0.170898
# 75%    2699.250000     57.810000  3.049000e+01   150.300000
# max    3599.000000     57.820000  3.049000e+01   177.400000

# %%
# Plot the CPU stats
plt.figure(figsize=(20,10))
plt.plot(cpu_stats['preprocessor'], label='preprocessor')
plt.plot(cpu_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(cpu_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('CPU Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('CPU Usage (%)')
plt.show()

# %%
# Plot the Memory stats
plt.figure(figsize=(20,10))
plt.plot(memory_stats['preprocessor'], label='preprocessor')
plt.plot(memory_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(memory_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('Memory Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('Memory Usage (MiB)')
plt.show()
