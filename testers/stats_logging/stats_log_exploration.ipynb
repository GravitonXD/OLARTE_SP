# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Open cpu_stats and memory_stats files
cpu_stats = pd.read_csv('cpu_stats.csv')
memory_stats = pd.read_csv('memory_stats.csv')

# %%
cpu_stats.head(10)
# Out:
#    time(s)  preprocessor  alamAPI_API  alamAPI_DB
# 0        0          0.03         0.20        0.19
# 1        1          0.03         0.14        0.24
# 2        2          0.02         0.14        0.19
# 3        3          0.04         0.21        0.21
# 4        4          0.35         0.29        0.37
# 5        5          0.03         0.20        0.23
# 6        6          0.03         0.22        0.44
# 7        7          0.03         0.19        0.27
# 8        8          0.03         0.26        0.25
# 9        9          0.03         0.23        1.04

# %%
cpu_stats.describe()
# Out:
#            time(s)  preprocessor  alamAPI_API   alamAPI_DB
# count  5287.000000   5287.000000  5287.000000  5287.000000
# mean   2643.000000      0.046378     0.232875     0.412132
# std    1526.369767      0.026893     0.052657     0.247744
# min       0.000000      0.020000     0.110000     0.140000
# 25%    1321.500000      0.030000     0.200000     0.270000
# 50%    2643.000000      0.040000     0.230000     0.350000
# 75%    3964.500000      0.050000     0.260000     0.470000
# max    5286.000000      0.350000     0.500000     1.940000

# %%
memory_stats.head(10)
# Out:
#    time(s)  preprocessor  alamAPI_API  alamAPI_DB
# 0        0         63.98        32.56       168.1
# 1        1         63.98        32.56       168.1
# 2        2         63.98        32.56       168.2
# 3        3         63.98        32.56       168.1
# 4        4         63.98        32.56       168.3
# 5        5         63.98        32.56       168.1
# 6        6         63.98        32.56       168.1
# 7        7         63.98        32.56       168.1
# 8        8         63.98        32.56       168.1
# 9        9         63.98        32.56       168.1

# %%
memory_stats.describe()
# Out:
#            time(s)  preprocessor  alamAPI_API   alamAPI_DB
# count  5287.000000  5.287000e+03      5287.00  5287.000000
# mean   2643.000000  6.398000e+01        32.56   182.658302
# std    1526.369767  7.106099e-15         0.00     5.734207
# min       0.000000  6.398000e+01        32.56     0.180664
# 25%    1321.500000  6.398000e+01        32.56   184.200000
# 50%    2643.000000  6.398000e+01        32.56   184.200000
# 75%    3964.500000  6.398000e+01        32.56   184.200000
# max    5286.000000  6.398000e+01        32.56   185.500000

# %%
# Plot the CPU stats
plt.figure(figsize=(20,10))
plt.plot(cpu_stats['preprocessor'], label='preprocessor')
plt.plot(cpu_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(cpu_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('CPU Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('CPU Usage (%)')
plt.show()
