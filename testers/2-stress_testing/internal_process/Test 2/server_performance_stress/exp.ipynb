# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Open cpu_stats and memory_stats files
cpu_stats = pd.read_csv('./processed_data/cpu_stats.csv')
memory_stats = pd.read_csv('./processed_data/memory_stats.csv')
network_stats = pd.read_csv('./processed_data/network_stats.csv')

# %%
cpu_stats.describe()
# Out:
#           time(s)  preprocessor  alamAPI_API  alamAPI_DB
# count  298.000000    298.000000   298.000000  298.000000
# mean   148.500000     92.711174     0.120302    0.313523
# std     86.169407     13.543555     0.022253    0.354923
# min      0.000000     40.260000     0.090000    0.120000
# 25%     74.250000     96.572500     0.110000    0.140000
# 50%    148.500000     97.800000     0.110000    0.160000
# 75%    222.750000     98.660000     0.130000    0.310000
# max    297.000000     99.990000     0.300000    2.150000

# %%
memory_stats.describe()
# Out:
#           time(s)  preprocessor  alamAPI_API  alamAPI_DB
# count  414.000000    414.000000   414.000000  414.000000
# mean   206.500000     57.095452    45.884783  191.915459
# std    119.655756    225.900169     0.088470    0.934775
# min      0.000000      1.001000    45.680000  189.500000
# 25%    103.250000      1.109000    45.820000  191.400000
# 50%    206.500000      1.173000    45.890000  192.000000
# 75%    309.750000      1.238750    45.960000  192.700000
# max    413.000000   1021.000000    46.010000  193.200000

# %%
network_stats.describe()
# Out:
#           time(s)  preprocessor  alamAPI_API  alamAPI_DB
# count  414.000000         414.0   414.000000  414.000000
# mean   206.500000         154.0     0.280250    1.748575
# std    119.655756           0.0     0.006874    0.301830
# min      0.000000         154.0     0.268555    1.230000
# 25%    103.250000         154.0     0.274414    1.490000
# 50%    206.500000         154.0     0.280273    1.750000
# 75%    309.750000         154.0     0.286133    2.010000
# max    413.000000         154.0     0.291992    2.270000

# %%
# Plot the CPU stats
plt.figure(figsize=(20,10))
plt.plot(cpu_stats['preprocessor'], label='preprocessor')
plt.plot(cpu_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(cpu_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('CPU Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('CPU Usage (%)')
plt.show()

# %%
# Plot the Memory stats
plt.figure(figsize=(20,10))
plt.plot(memory_stats['preprocessor'], label='preprocessor')
plt.plot(memory_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(memory_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('Memory Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('Memory Usage (MiB)')
plt.show()

# %%
# Plot the Network stats
plt.figure(figsize=(20,10))
plt.plot(network_stats['preprocessor'], label='preprocessor')
plt.plot(network_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(network_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('Network Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('Network Usage (MB)')
plt.show()
