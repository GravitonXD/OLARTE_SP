# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Open cpu_stats and memory_stats files
cpu_stats = pd.read_csv('./processed_data/cpu_stats.csv')
memory_stats = pd.read_csv('./processed_data/memory_stats.csv')
network_stats = pd.read_csv('./processed_data/network_stats.csv')

# %%
cpu_stats.describe()
# Out:
#           time(s)  preprocessor  alamAPI_API   alamAPI_DB
# count  2041.00000   2041.000000  2041.000000  2041.000000
# mean   1020.00000     11.406585     0.196418     0.348364
# std     589.33027     37.637443     0.049950     0.235611
# min       0.00000      0.020000     0.100000     0.130000
# 25%     510.00000      0.690000     0.160000     0.220000
# 50%    1020.00000      1.520000     0.190000     0.280000
# 75%    1530.00000      2.710000     0.220000     0.400000
# max    2040.00000    181.890000     0.600000     3.050000

# %%
memory_stats.describe()
# Out:
#           time(s)  preprocessor  alamAPI_API   alamAPI_DB
# count  2041.00000   2041.000000  2041.000000  2041.000000
# mean   1020.00000      3.641999    45.582063   188.113474
# std     589.33027     49.408408     0.083436     1.214952
# min       0.00000      1.000000    45.490000   186.400000
# 25%     510.00000      1.160000    45.500000   186.800000
# 50%    1020.00000      1.195000    45.550000   188.100000
# 75%    1530.00000      1.232000    45.680000   189.500000
# max    2040.00000   1013.000000    45.720000   190.000000

# %%
network_stats.describe()
# Out:
#           time(s)  preprocessor  alamAPI_API   alamAPI_DB
# count  2041.00000   2041.000000  2041.000000  2041.000000
# mean   1020.00000    232.736404     0.373212     2.395532
# std     589.33027     43.916923     0.034026     0.053082
# min       0.00000    156.000000     0.314453     2.300000
# 25%     510.00000    195.000000     0.343750     2.350000
# 50%    1020.00000    233.000000     0.373047     2.400000
# 75%    1530.00000    271.000000     0.402344     2.440000
# max    2040.00000    309.000000     0.432617     2.490000

# %%
# Plot the CPU stats
plt.figure(figsize=(20,10))
plt.plot(cpu_stats['preprocessor'], label='preprocessor')
plt.plot(cpu_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(cpu_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('CPU Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('CPU Usage (%)')
plt.show()

# %%
# Plot the Memory stats
plt.figure(figsize=(20,10))
plt.plot(memory_stats['preprocessor'], label='preprocessor')
plt.plot(memory_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(memory_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('Memory Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('Memory Usage (MiB)')
plt.show()

# %%
# Plot the Network stats
plt.figure(figsize=(20,10))
plt.plot(network_stats['preprocessor'], label='preprocessor')
plt.plot(network_stats['alamAPI_API'], label='alamAPI_API')
plt.plot(network_stats['alamAPI_DB'], label='alamAPI_DB')
plt.legend()
plt.title('Network Stats')
plt.xlabel('Time (seconds)')
plt.ylabel('Network Usage (MB)')
plt.show()
