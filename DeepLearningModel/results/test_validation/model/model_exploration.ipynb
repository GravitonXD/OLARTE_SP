# %%
import pandas as pd

# %%
df = pd.read_csv('model_s5.csv', index_col=0)
df = df.sort_index()
df
# Out:
#                 MSE        RMSE         MAE      MAPE
# AC       334.596086   18.291968   12.152423  0.033886
# ALI        0.888378    0.942538    0.612138  0.036234
# AP         0.869306    0.932366    0.659025  0.025030
# BDO        9.437371    3.072030    1.917598  0.027811
# BLOOM      6.424741    2.534707    0.707406  0.068108
# FGEN       0.697390    0.835099    0.589689  0.032449
# GLO     3485.954319   59.041971   36.287456  0.031104
# ICT        8.046283    2.836597    1.446341  0.037207
# JGS        2.768997    1.664030    0.909225  0.039754
# LTG        0.579147    0.761017    0.456835  0.057332
# MEG        0.018316    0.135336    0.089568  0.044411
# MER       57.848920    7.605848    4.772926  0.037546
# MPI        0.045508    0.213325    0.142975  0.033738
# PGOLD      2.051151    1.432184    1.053508  0.028002
# PSEI   31669.602701  177.959554  128.609522  0.019111
# RLC        0.474353    0.688733    0.446334  0.039573
# RRHI       6.239762    2.497952    1.873154  0.026765
# SMC        9.741641    3.121160    1.633596  0.022560
# TEL     4258.850672   65.259870   44.221286  0.029942
# URC       12.778722    3.574734    2.020836  0.037336

# %%
df.describe()
# Out:
#                 MSE        RMSE         MAE       MAPE
# count     20.000000   20.000000   20.000000  20.000000
# mean    1993.395688   17.670051   12.030092   0.035395
# std     7085.554995   42.067177   30.007693   0.011396
# min        0.018316    0.135336    0.089568   0.019111
# 25%        0.826327    0.908049    0.606526   0.027955
# 50%        6.332251    2.516329    1.249925   0.033812
# 75%       24.046271    4.582512    2.708858   0.038053
# max    31669.602701  177.959554  128.609522   0.068108

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

# %%
# Plot the MSE distribution and add a normal distribution on top
plt.hist(df['MSE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['MSE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "MSE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
# Plot the RMSE distribution and add a normal distribution on top
plt.hist(df['RMSE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['RMSE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "RMSE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
# Plot the MAE distribution and add a normal distribution on top
plt.hist(df['MAE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['MAE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "MAE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %%
# Plot the MAPE distribution and add a normal distribution on top
plt.hist(df['MAPE'], bins=5, density=True, alpha=0.6, color='g')
mu, std = norm.fit(df['MAPE'])
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "MAPE distribution. mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()
